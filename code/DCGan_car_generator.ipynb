# %%
from __future__ import print_function
import os
import matplotlib as mpl
import tarfile
import matplotlib.image as mpimg
from matplotlib import pyplot as plt

import mxnet as mx
from mxnet import gluon
from mxnet import ndarray as nd
from mxnet.gluon import nn, utils
from mxnet import autograd
import numpy as np

# %%
epochs = 10 # Set low by default for tests, set higher when you actually run this code.
batch_size = 64
latent_z_size = 100

use_gpu = False
ctx = mx.gpu() if use_gpu else mx.cpu()

lr = 0.0002
beta1 = 0.5

# %%
lfw_url = 'http://vis-www.cs.umass.edu/lfw/lfw-deepfunneled.tgz'
data_path = 'lfw_dataset'
if not os.path.exists(data_path):
    os.makedirs(data_path)
    data_file = utils.download(lfw_url)
    with tarfile.open(data_file) as tar:
        tar.extractall(path=data_path)
# Out:
# Downloading lfw-deepfunneled.tgz from http://vis-www.cs.umass.edu/lfw/lfw-deepfunneled.tgz...

# %%
cars_url = 'http://imagenet.stanford.edu/internal/car196/cars_train.tgz'
data_path = 'cars_dataset'
if not os.path.exists(data_path):
    os.makedirs(data_path)
    data_file = utils.download(cars_url)
    with tarfile.open(data_file) as tar:
        tar.extractall(path=data_path)

# %%
target_wd = 64
target_ht = 64
img_list = []

def transform(data, target_wd, target_ht):
    # resize to target_wd * target_ht
    data = mx.image.imresize(data, target_wd, target_ht)
    # transpose from (target_wd, target_ht, 3)
    # to (3, target_wd, target_ht)
    data = nd.transpose(data, (2,0,1))
    # normalize to [-1, 1]
    data = data.astype(np.float32)/127.5 - 1
    # if image is greyscale, repeat 3 times to get RGB image.
    if data.shape[0] == 1:
        data = nd.tile(data, (3, 1, 1))
    return data.reshape((1,) + data.shape)

for path, _, fnames in os.walk(data_path):
    for fname in fnames:
        if not fname.endswith('.jpg'):
            continue
        img = os.path.join(path, fname)
        img_arr = mx.image.imread(img)
        img_arr = transform(img_arr, target_wd, target_ht)
        img_list.append(img_arr)
train_data = mx.io.NDArrayIter(data=nd.concatenate(img_list), batch_size=batch_size)

# %%
def visualize(img_arr):
    plt.imshow(((img_arr.asnumpy().transpose(1, 2, 0) + 1.0) * 127.5).astype(np.uint8))
    plt.axis('off')

for i in range(4):
    plt.subplot(1,4,i+1)
    visualize(img_list[i + 11][0])
plt.show()

# %%
# build the generator
nc = 3
ngf = 64
netG = nn.Sequential()
with netG.name_scope():
    # input is Z, going into a convolution
    netG.add(nn.Conv2DTranspose(ngf * 8, 4, 1, 0, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. (ngf*8) x 4 x 4
    netG.add(nn.Conv2DTranspose(ngf * 4, 4, 2, 1, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. (ngf*8) x 8 x 8
    netG.add(nn.Conv2DTranspose(ngf * 2, 4, 2, 1, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. (ngf*8) x 16 x 16
    netG.add(nn.Conv2DTranspose(ngf, 4, 2, 1, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. (ngf*8) x 32 x 32
    netG.add(nn.Conv2DTranspose(nc, 4, 2, 1, use_bias=False))
    netG.add(nn.Activation('tanh'))
    # state size. (nc) x 64 x 64

# build the discriminator
ndf = 64
netD = nn.Sequential()
with netD.name_scope():
    # input is (nc) x 64 x 64
    netD.add(nn.Conv2D(ndf, 4, 2, 1, use_bias=False))
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf) x 32 x 32
    netD.add(nn.Conv2D(ndf * 2, 4, 2, 1, use_bias=False))
    netD.add(nn.BatchNorm())
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf) x 16 x 16
    netD.add(nn.Conv2D(ndf * 4, 4, 2, 1, use_bias=False))
    netD.add(nn.BatchNorm())
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf) x 8 x 8
    netD.add(nn.Conv2D(ndf * 8, 4, 2, 1, use_bias=False))
    netD.add(nn.BatchNorm())
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf) x 4 x 4
    netD.add(nn.Conv2D(1, 4, 1, 0, use_bias=False))

# %%
# loss
loss = gluon.loss.SigmoidBinaryCrossEntropyLoss()

# initialize the generator and the discriminator
netG.initialize(mx.init.Normal(0.02), ctx=ctx)
netD.initialize(mx.init.Normal(0.02), ctx=ctx)

# trainer for the generator and the discriminator
trainerG = gluon.Trainer(netG.collect_params(), 'adam', {'learning_rate': lr, 'beta1': beta1})
trainerD = gluon.Trainer(netD.collect_params(), 'adam', {'learning_rate': lr, 'beta1': beta1})

# %%
from datetime import datetime
import time
import logging

real_label = nd.ones((batch_size,),ctx=ctx)
fake_label = nd.zeros((batch_size,),ctx=ctx)

def facc(label, pred):
    pred = pred.ravel()
    label = label.ravel()
    return ((pred > 0.5) == label).mean()
metric = mx.metric.CustomMetric(facc)

stamp =  datetime.now().strftime('%Y_%m_%d-%H_%M')
logging.basicConfig(level=logging.DEBUG)

for epoch in range(epochs):
    tic = time.time()
    btic = time.time()
    train_data.reset()
    iter = 0
    for batch in train_data:
        ############################
        # (1) Update D network: maximize log(D(x)) + log(1 - D(G(z)))
        ###########################
        data = batch.data[0].as_in_context(ctx)
        latent_z = mx.nd.random_normal(0, 1, shape=(batch_size, latent_z_size, 1, 1), ctx=ctx)

        with autograd.record():
            # train with real image
            output = netD(data).reshape((-1, 1))
            errD_real = loss(output, real_label)
            metric.update([real_label,], [output,])

            # train with fake image
            fake = netG(latent_z)
            output = netD(fake).reshape((-1, 1))
            errD_fake = loss(output, fake_label)
            errD = errD_real + errD_fake
            errD.backward()
            metric.update([fake_label,], [output,])

        trainerD.step(batch.data[0].shape[0])

        ############################
        # (2) Update G network: maximize log(D(G(z)))
        ###########################
        with autograd.record():
            fake = netG(latent_z)
            output = netD(fake).reshape((-1, 1))
            errG = loss(output, real_label)
            errG.backward()

        trainerG.step(batch.data[0].shape[0])

        # Print log infomation every ten batches
        if iter % 10 == 0:
            name, acc = metric.get()
            logging.info('speed: {} samples/s'.format(batch_size / (time.time() - btic)))
            logging.info('discriminator loss = %f, generator loss = %f, binary training acc = %f at iter %d epoch %d'
                     %(nd.mean(errD).asscalar(),
                       nd.mean(errG).asscalar(), acc, iter, epoch))
        iter = iter + 1
        btic = time.time()

    name, acc = metric.get()
    metric.reset()
    # logging.info('\nbinary training acc at epoch %d: %s=%f' % (epoch, name, acc))
    # logging.info('time: %f' % (time.time() - tic))

    # Visualize one generated image for each epoch
    # fake_img = fake[0]
    # visualize(fake_img)
    # plt.show()
# Out:
# INFO:root:speed: 28.954262083652743 samples/s
# INFO:root:discriminator loss = 1.746364, generator loss = 6.763268, binary training acc = 0.523438 at iter 0 epoch 0
# INFO:root:speed: 9.758049281891166 samples/s
# INFO:root:discriminator loss = 1.056928, generator loss = 10.835676, binary training acc = 0.814631 at iter 10 epoch 0
# INFO:root:speed: 9.783013647068564 samples/s
# INFO:root:discriminator loss = 0.885689, generator loss = 16.997408, binary training acc = 0.841518 at iter 20 epoch 0
# INFO:root:speed: 9.794898276413177 samples/s
# INFO:root:discriminator loss = 0.353614, generator loss = 6.075672, binary training acc = 0.829385 at iter 30 epoch 0
# INFO:root:speed: 8.361986310021685 samples/s
# INFO:root:discriminator loss = 0.140380, generator loss = 11.281589, binary training acc = 0.829649 at iter 40 epoch 0
# INFO:root:speed: 9.463242924648446 samples/s
# INFO:root:discriminator loss = 0.336075, generator loss = 20.596552, binary training acc = 0.844822 at iter 50 epoch 0
# INFO:root:speed: 9.470151372581338 samples/s
# INFO:root:discriminator loss = 0.146834, generator loss = 3.067725, binary training acc = 0.835041 at iter 60 epoch 0
# INFO:root:speed: 9.67634332999957 samples/s
# INFO:root:discriminator loss = 1.451127, generator loss = 8.820738, binary training acc = 0.826364 at iter 70 epoch 0
# INFO:root:speed: 9.822491647227972 samples/s
# INFO:root:discriminator loss = 0.398325, generator loss = 6.791010, binary training acc = 0.824556 at iter 80 epoch 0
# INFO:root:speed: 9.898266925865725 samples/s
# INFO:root:discriminator loss = 1.253775, generator loss = 3.898584, binary training acc = 0.817909 at iter 90 epoch 0
# INFO:root:speed: 9.728500018863693 samples/s
# INFO:root:discriminator loss = 0.778151, generator loss = 4.637814, binary training acc = 0.851562 at iter 0 epoch 1
# INFO:root:speed: 9.817314401926573 samples/s
# INFO:root:discriminator loss = 0.583720, generator loss = 2.953262, binary training acc = 0.818182 at iter 10 epoch 1
# INFO:root:speed: 9.915559184541896 samples/s
# INFO:root:discriminator loss = 0.413872, generator loss = 4.232838, binary training acc = 0.835938 at iter 20 epoch 1
# INFO:root:speed: 9.80435108863778 samples/s
# INFO:root:discriminator loss = 0.829762, generator loss = 4.161750, binary training acc = 0.843246 at iter 30 epoch 1
# INFO:root:speed: 9.941870921857475 samples/s
# INFO:root:discriminator loss = 0.768029, generator loss = 4.885225, binary training acc = 0.834985 at iter 40 epoch 1
# INFO:root:speed: 9.777156389545784 samples/s
# INFO:root:discriminator loss = 1.037895, generator loss = 6.418297, binary training acc = 0.820772 at iter 50 epoch 1
# INFO:root:speed: 9.795730384706783 samples/s
# INFO:root:discriminator loss = 0.797500, generator loss = 3.593743, binary training acc = 0.820569 at iter 60 epoch 1
# INFO:root:speed: 9.796876552229396 samples/s
# INFO:root:discriminator loss = 0.625053, generator loss = 4.104789, binary training acc = 0.819982 at iter 70 epoch 1
# INFO:root:speed: 9.779407172240411 samples/s
# INFO:root:discriminator loss = 0.554264, generator loss = 4.890733, binary training acc = 0.827064 at iter 80 epoch 1
# INFO:root:speed: 9.84090401180166 samples/s
# INFO:root:discriminator loss = 0.535945, generator loss = 4.030177, binary training acc = 0.832160 at iter 90 epoch 1
# INFO:root:speed: 9.819527677991006 samples/s
# INFO:root:discriminator loss = 1.042170, generator loss = 7.082533, binary training acc = 0.671875 at iter 0 epoch 2
# INFO:root:speed: 9.896597752825228 samples/s
# INFO:root:discriminator loss = 0.407159, generator loss = 4.776845, binary training acc = 0.862216 at iter 10 epoch 2
# INFO:root:speed: 9.782341976188246 samples/s
# INFO:root:discriminator loss = 0.403940, generator loss = 5.187542, binary training acc = 0.887277 at iter 20 epoch 2
# INFO:root:speed: 9.927025145191303 samples/s
# INFO:root:discriminator loss = 0.381373, generator loss = 6.984457, binary training acc = 0.881300 at iter 30 epoch 2
# INFO:root:speed: 9.887238708332902 samples/s
# INFO:root:discriminator loss = 0.498071, generator loss = 5.375113, binary training acc = 0.883003 at iter 40 epoch 2
# INFO:root:speed: 9.931904255473444 samples/s
# INFO:root:discriminator loss = 0.779838, generator loss = 4.505961, binary training acc = 0.882659 at iter 50 epoch 2
# INFO:root:speed: 9.84827825562482 samples/s
# INFO:root:discriminator loss = 0.639360, generator loss = 3.118107, binary training acc = 0.881148 at iter 60 epoch 2
# INFO:root:speed: 9.799261268337329 samples/s
# INFO:root:discriminator loss = 0.531360, generator loss = 6.022061, binary training acc = 0.877531 at iter 70 epoch 2
# INFO:root:speed: 9.773246076035715 samples/s
# INFO:root:discriminator loss = 0.633969, generator loss = 5.166028, binary training acc = 0.871914 at iter 80 epoch 2
# INFO:root:speed: 9.888721487202833 samples/s
# INFO:root:discriminator loss = 0.584256, generator loss = 5.298028, binary training acc = 0.871223 at iter 90 epoch 2
# INFO:root:speed: 9.859758176191542 samples/s
# INFO:root:discriminator loss = 0.608932, generator loss = 5.637336, binary training acc = 0.929688 at iter 0 epoch 3
# INFO:root:speed: 9.849032007290843 samples/s
# INFO:root:discriminator loss = 0.389864, generator loss = 3.063684, binary training acc = 0.818892 at iter 10 epoch 3
# INFO:root:speed: 9.746370982045555 samples/s
# INFO:root:discriminator loss = 0.431872, generator loss = 4.570188, binary training acc = 0.866443 at iter 20 epoch 3
# INFO:root:speed: 9.956972051496265 samples/s
# INFO:root:discriminator loss = 0.524950, generator loss = 4.297571, binary training acc = 0.884073 at iter 30 epoch 3
# INFO:root:speed: 9.860003360186171 samples/s
# INFO:root:discriminator loss = 0.263640, generator loss = 5.097428, binary training acc = 0.891768 at iter 40 epoch 3
# INFO:root:speed: 9.858055262599109 samples/s
# INFO:root:discriminator loss = 0.226389, generator loss = 6.809904, binary training acc = 0.896599 at iter 50 epoch 3
# INFO:root:speed: 9.806189891365493 samples/s
# INFO:root:discriminator loss = 0.772543, generator loss = 2.450854, binary training acc = 0.893058 at iter 60 epoch 3
# INFO:root:speed: 9.95265756101482 samples/s
# INFO:root:discriminator loss = 0.396035, generator loss = 4.180676, binary training acc = 0.880722 at iter 70 epoch 3
# INFO:root:speed: 9.71022798694675 samples/s
# INFO:root:discriminator loss = 0.713921, generator loss = 5.725854, binary training acc = 0.879630 at iter 80 epoch 3
# INFO:root:speed: 9.868538794428982 samples/s
# INFO:root:discriminator loss = 0.724528, generator loss = 5.623864, binary training acc = 0.870622 at iter 90 epoch 3
# INFO:root:speed: 9.947044763533762 samples/s
# INFO:root:discriminator loss = 0.425134, generator loss = 3.365129, binary training acc = 0.898438 at iter 0 epoch 4
# INFO:root:speed: 9.61002610044788 samples/s
# INFO:root:discriminator loss = 0.402903, generator loss = 4.995516, binary training acc = 0.892756 at iter 10 epoch 4
# INFO:root:speed: 9.823425152295126 samples/s
# INFO:root:discriminator loss = 0.403721, generator loss = 4.197196, binary training acc = 0.906622 at iter 20 epoch 4
# INFO:root:speed: 9.895471543383865 samples/s
# INFO:root:discriminator loss = 0.682849, generator loss = 4.937116, binary training acc = 0.907510 at iter 30 epoch 4
# INFO:root:speed: 9.91229647765582 samples/s
# INFO:root:discriminator loss = 0.967500, generator loss = 6.462881, binary training acc = 0.911204 at iter 40 epoch 4
# INFO:root:speed: 9.796158289241543 samples/s
# INFO:root:discriminator loss = 0.411728, generator loss = 3.110358, binary training acc = 0.908548 at iter 50 epoch 4
# INFO:root:speed: 9.519398958437282 samples/s
# INFO:root:discriminator loss = 0.334557, generator loss = 3.636934, binary training acc = 0.916112 at iter 60 epoch 4
# INFO:root:speed: 9.853962783297508 samples/s
# INFO:root:discriminator loss = 0.304896, generator loss = 4.024311, binary training acc = 0.922755 at iter 70 epoch 4
# INFO:root:speed: 9.790763780403209 samples/s
# INFO:root:discriminator loss = 0.285001, generator loss = 5.531429, binary training acc = 0.925058 at iter 80 epoch 4
# INFO:root:speed: 9.61363609422053 samples/s
# INFO:root:discriminator loss = 0.268257, generator loss = 4.414424, binary training acc = 0.922562 at iter 90 epoch 4
# INFO:root:speed: 9.81481718057913 samples/s
# INFO:root:discriminator loss = 0.197792, generator loss = 4.648486, binary training acc = 0.984375 at iter 0 epoch 5
# INFO:root:speed: 9.695464508884843 samples/s
# INFO:root:discriminator loss = 0.310163, generator loss = 3.911098, binary training acc = 0.951705 at iter 10 epoch 5
# INFO:root:speed: 9.856285261674042 samples/s
# INFO:root:discriminator loss = 0.271316, generator loss = 5.057333, binary training acc = 0.955357 at iter 20 epoch 5
# INFO:root:speed: 9.85214471285342 samples/s
# INFO:root:discriminator loss = 0.469907, generator loss = 2.826221, binary training acc = 0.953377 at iter 30 epoch 5
# INFO:root:speed: 9.706056553091155 samples/s
# INFO:root:discriminator loss = 0.276432, generator loss = 4.080307, binary training acc = 0.950267 at iter 40 epoch 5
# INFO:root:speed: 9.78711376541987 samples/s
# INFO:root:discriminator loss = 0.544941, generator loss = 3.238573, binary training acc = 0.943627 at iter 50 epoch 5
# INFO:root:speed: 9.678274001824567 samples/s
# INFO:root:discriminator loss = 0.184946, generator loss = 4.680040, binary training acc = 0.938909 at iter 60 epoch 5
# INFO:root:speed: 9.627018999625909 samples/s
# INFO:root:discriminator loss = 1.128354, generator loss = 0.230422, binary training acc = 0.930348 at iter 70 epoch 5
# INFO:root:speed: 9.866053523180527 samples/s
# INFO:root:discriminator loss = 0.607623, generator loss = 3.082460, binary training acc = 0.912616 at iter 80 epoch 5
# INFO:root:speed: 9.67485451070516 samples/s
# INFO:root:discriminator loss = 0.658778, generator loss = 7.396314, binary training acc = 0.909770 at iter 90 epoch 5
# INFO:root:speed: 9.843717376824202 samples/s
# INFO:root:discriminator loss = 0.132610, generator loss = 4.818851, binary training acc = 0.984375 at iter 0 epoch 6
# INFO:root:speed: 9.877174425338627 samples/s
# INFO:root:discriminator loss = 0.243275, generator loss = 4.309801, binary training acc = 0.953835 at iter 10 epoch 6
# INFO:root:speed: 9.802665826855202 samples/s
# INFO:root:discriminator loss = 0.215916, generator loss = 4.273021, binary training acc = 0.959821 at iter 20 epoch 6
# INFO:root:speed: 9.586071948751714 samples/s
# INFO:root:discriminator loss = 0.374138, generator loss = 4.750595, binary training acc = 0.953881 at iter 30 epoch 6
# INFO:root:speed: 9.86333428965154 samples/s
# INFO:root:discriminator loss = 0.401318, generator loss = 5.541041, binary training acc = 0.954649 at iter 40 epoch 6
# INFO:root:speed: 9.82452423412687 samples/s
# INFO:root:discriminator loss = 0.608350, generator loss = 7.115958, binary training acc = 0.950368 at iter 50 epoch 6
# INFO:root:speed: 9.67788913170949 samples/s
# INFO:root:discriminator loss = 0.344560, generator loss = 4.622427, binary training acc = 0.951332 at iter 60 epoch 6
# INFO:root:speed: 9.870420990656402 samples/s
# INFO:root:discriminator loss = 0.132476, generator loss = 4.112871, binary training acc = 0.952465 at iter 70 epoch 6
# INFO:root:speed: 9.795432982690501 samples/s
# INFO:root:discriminator loss = 0.198585, generator loss = 4.723538, binary training acc = 0.951196 at iter 80 epoch 6
# INFO:root:speed: 9.824006480938419 samples/s
# INFO:root:discriminator loss = 1.104275, generator loss = 11.750307, binary training acc = 0.949176 at iter 90 epoch 6
# INFO:root:speed: 9.871048185974814 samples/s
# INFO:root:discriminator loss = 0.523994, generator loss = 7.323809, binary training acc = 0.906250 at iter 0 epoch 7
# INFO:root:speed: 9.765285619067527 samples/s
# INFO:root:discriminator loss = 0.503397, generator loss = 5.591224, binary training acc = 0.776278 at iter 10 epoch 7
# INFO:root:speed: 9.306031803635106 samples/s
# INFO:root:discriminator loss = 0.525448, generator loss = 4.937133, binary training acc = 0.831101 at iter 20 epoch 7
# INFO:root:speed: 9.704969079620092 samples/s
# INFO:root:discriminator loss = 0.529789, generator loss = 3.507820, binary training acc = 0.860131 at iter 30 epoch 7
# INFO:root:speed: 9.599164653992961 samples/s
# INFO:root:discriminator loss = 0.337353, generator loss = 3.817603, binary training acc = 0.883003 at iter 40 epoch 7
# INFO:root:speed: 9.78173990378284 samples/s
# INFO:root:discriminator loss = 0.332176, generator loss = 3.787438, binary training acc = 0.896906 at iter 50 epoch 7
# INFO:root:speed: 9.94360844337924 samples/s
# INFO:root:discriminator loss = 0.323011, generator loss = 4.818015, binary training acc = 0.908555 at iter 60 epoch 7
# INFO:root:speed: 9.788420675548108 samples/s
# INFO:root:discriminator loss = 0.385907, generator loss = 3.990068, binary training acc = 0.906910 at iter 70 epoch 7
# INFO:root:speed: 9.85698449896486 samples/s
# INFO:root:discriminator loss = 0.634925, generator loss = 6.468776, binary training acc = 0.902392 at iter 80 epoch 7
# INFO:root:speed: 9.752257654620077 samples/s
# INFO:root:discriminator loss = 1.101138, generator loss = 8.939929, binary training acc = 0.897493 at iter 90 epoch 7
# INFO:root:speed: 9.833504059832558 samples/s
# INFO:root:discriminator loss = 0.378399, generator loss = 5.129941, binary training acc = 0.945312 at iter 0 epoch 8
# INFO:root:speed: 9.833083332249664 samples/s
# INFO:root:discriminator loss = 0.426514, generator loss = 5.493602, binary training acc = 0.929688 at iter 10 epoch 8
# INFO:root:speed: 9.927897846696299 samples/s
# INFO:root:discriminator loss = 0.305411, generator loss = 3.796299, binary training acc = 0.930432 at iter 20 epoch 8
# INFO:root:speed: 9.860980957926541 samples/s
# INFO:root:discriminator loss = 0.159880, generator loss = 2.494029, binary training acc = 0.913306 at iter 30 epoch 8
# INFO:root:speed: 9.857985029593552 samples/s
# INFO:root:discriminator loss = 0.275687, generator loss = 4.543392, binary training acc = 0.914062 at iter 40 epoch 8
# INFO:root:speed: 9.794470839319066 samples/s
# INFO:root:discriminator loss = 0.434852, generator loss = 5.841419, binary training acc = 0.914216 at iter 50 epoch 8
# INFO:root:speed: 9.938071335857261 samples/s
# INFO:root:discriminator loss = 0.423826, generator loss = 4.007088, binary training acc = 0.917649 at iter 60 epoch 8
# INFO:root:speed: 9.896303680540553 samples/s
# INFO:root:discriminator loss = 0.251972, generator loss = 5.245373, binary training acc = 0.918574 at iter 70 epoch 8
# INFO:root:speed: 9.893047433034315 samples/s
# INFO:root:discriminator loss = 0.264839, generator loss = 5.118238, binary training acc = 0.909529 at iter 80 epoch 8
# INFO:root:speed: 9.987353974239081 samples/s
# INFO:root:discriminator loss = 0.517366, generator loss = 3.894030, binary training acc = 0.903245 at iter 90 epoch 8
# INFO:root:speed: 9.954740689894047 samples/s
# INFO:root:discriminator loss = 0.355176, generator loss = 4.692779, binary training acc = 0.906250 at iter 0 epoch 9
# INFO:root:speed: 9.894540707911007 samples/s
# INFO:root:discriminator loss = 0.491475, generator loss = 6.873402, binary training acc = 0.893466 at iter 10 epoch 9
# INFO:root:speed: 9.82785138092363 samples/s
# INFO:root:discriminator loss = 0.687596, generator loss = 5.413422, binary training acc = 0.902530 at iter 20 epoch 9
# INFO:root:speed: 9.748987150832429 samples/s
# INFO:root:discriminator loss = 0.502810, generator loss = 3.656037, binary training acc = 0.922379 at iter 30 epoch 9
# INFO:root:speed: 9.659803066805484 samples/s
# INFO:root:discriminator loss = 0.883902, generator loss = 8.814412, binary training acc = 0.917683 at iter 40 epoch 9
# INFO:root:speed: 9.815202252020809 samples/s
# INFO:root:discriminator loss = 0.315899, generator loss = 3.635656, binary training acc = 0.915288 at iter 50 epoch 9
# INFO:root:speed: 9.201606448610313 samples/s
# INFO:root:discriminator loss = 0.402110, generator loss = 3.634581, binary training acc = 0.905866 at iter 60 epoch 9
# INFO:root:speed: 9.800424363659875 samples/s
# INFO:root:discriminator loss = 0.234781, generator loss = 5.502689, binary training acc = 0.911202 at iter 70 epoch 9
# INFO:root:speed: 9.70930849592981 samples/s
# INFO:root:discriminator loss = 0.263978, generator loss = 5.515885, binary training acc = 0.911941 at iter 80 epoch 9
# INFO:root:speed: 9.574399468584014 samples/s
# INFO:root:discriminator loss = 0.556886, generator loss = 6.724252, binary training acc = 0.914835 at iter 90 epoch 9

# %%
num_image = 8
for i in range(num_image):
    latent_z = mx.nd.random_normal(0, 1, shape=(1, latent_z_size, 1, 1), ctx=ctx)
    img = netG(latent_z)
    plt.subplot(2,4,i+1)
    visualize(img[0])
plt.show()

# %%
num_image = 12
step = 0.05
for i in range(num_image):
    latent_z = mx.nd.random_normal(0, 1, shape=(1, latent_z_size, 1, 1), ctx=ctx)
    img = netG(latent_z)
    plt.subplot(3,4,i+1)
    visualize(img[0])
    latent_z += 0.05
plt.show()
